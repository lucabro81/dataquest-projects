# %% [markdown]
# # Exploring Ebay Car Sales Data
#
#
# In this project, we'll work with a dataset of used cars from eBay Kleinanzeigen, a classifieds section of the German eBay website.
#
# The dataset was originally scraped and uploaded to Kaggle.
#
# The aim of this project is to clean the data and analyze the included used car listings.

# %%
import pandas as pd
import numpy as np

autos = pd.read_csv('autos.csv', encoding='Latin-1')

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %% [markdown]
# - The dataset contains 20 columns, most of which are strings.
# - Some columns have null values, but none have more than ~20% null values.
# - The column names use camelcase instead of Python's preferred snakecase, which means we can't just replace spaces with underscores.
#
#
# Let's convert the column names from camelcase to snakecase and reword some of the column names based on the data dictionary to be more descriptive.

# %%
import re

def snakeize(match):
    return '_' + chr(ord(match[0])+32)

new_columns = []

for column in autos.columns:
    new_columns.append(re.sub(r'[A-Z]', snakeize, column))
    
autos.columns = new_columns

autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  year_of_registration  \
# 0  privat    Angebot  $5,000  control          bus                  2004
# 1  privat    Angebot  $8,500  control    limousine                  1997
# 2  privat    Angebot  $8,990     test    limousine                  2009
# 3  privat    Angebot  $4,350  control   kleinwagen                  2007
# 4  privat    Angebot  $1,350     test        kombi                  2003
#
#      gearbox  power_p_s   model   odometer  month_of_registration fuel_type  \
# ...

# %%
autos.describe(include='all')
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-04-02 11:37:04  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
# mean                    NaN          NaN     NaN        NaN    NaN    NaN
# std                     NaN          NaN     NaN        NaN    NaN    NaN
# min                     NaN          NaN     NaN        NaN    NaN    NaN
# 25%                     NaN          NaN     NaN        NaN    NaN    NaN
# 50%                     NaN          NaN     NaN        NaN    NaN    NaN
# 75%                     NaN          NaN     NaN        NaN    NaN    NaN
# max                     NaN          NaN     NaN        NaN    NaN    NaN
#
#        vehicle_type  year_of_registration  gearbox     power_p_s  model  \
# ...

# %% [markdown]
# Seller and offer_type has all (or nearly all) the same value:

# %%
autos['seller'].unique()
# Out:
# array(['privat', 'gewerblich'], dtype=object)

# %%
autos[autos['seller']=='gewerblich']
# Out:
#              date_crawled                                         name  \
# 7738  2016-03-15 18:06:22  Verkaufe_mehrere_Fahrzeuge_zum_Verschrotten
#
#           seller offer_type price   abtest vehicle_type  year_of_registration  \
# 7738  gewerblich    Angebot  $100  control        kombi                  2000
#
#       gearbox  power_p_s   model   odometer  month_of_registration fuel_type  \
# 7738  manuell          0  megane  150,000km                      8    benzin
#
#         brand not_repaired_damage         date_created  nr_of_pictures  \
# 7738  renault                 NaN  2016-03-15 00:00:00               0
#
#       postal_code            last_seen
# 7738        65232  2016-04-06 17:15:37

# %%
autos['offer_type'].unique()
# Out:
# array(['Angebot', 'Gesuch'], dtype=object)

# %%
autos[autos['offer_type']=='Gesuch']
# Out:
#               date_crawled                  name  seller offer_type price  \
# 17541  2016-04-03 15:48:33  Suche_VW_T5_Multivan  privat     Gesuch    $0
#
#       abtest vehicle_type  year_of_registration gearbox  power_p_s  \
# 17541   test          bus                  2005     NaN          0
#
#              model   odometer  month_of_registration fuel_type       brand  \
# 17541  transporter  150,000km                      0       NaN  volkswagen
#
#       not_repaired_damage         date_created  nr_of_pictures  postal_code  \
# 17541                 NaN  2016-04-03 00:00:00               0        29690
#
#                  last_seen
# 17541  2016-04-05 15:16:06

# %% [markdown]
# nr_of_pictures is formed by only 0

# %%
autos['nr_of_pictures'].unique()
# Out:
# array([0])

# %% [markdown]
# ### Clean data
#
# So we can erased from the face of the galaxy, seller, offer_type and nr_of_pictures

# %%
autos = autos.drop(['seller', 'offer_type', 'nr_of_pictures'], axis = 1)
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#     price   abtest vehicle_type  year_of_registration    gearbox  power_p_s  \
# 0  $5,000  control          bus                  2004    manuell        158
# 1  $8,500  control    limousine                  1997  automatik        286
# 2  $8,990     test    limousine                  2009    manuell        102
# 3  $4,350  control   kleinwagen                  2007  automatik         71
# 4  $1,350     test        kombi                  2003    manuell          0
#
# ...

# %% [markdown]
# Uh! price and odometer are strings! What a shame!

# %%
re_express = re.compile('[^\d.]')
autos['price'] = autos['price'].str.replace(re_express, '').astype(float)
autos['odometer'] = autos['odometer'].str.replace(re_express, '').astype(float)
autos.rename({'price': 'price_$', 'odometer': 'odometer_km'}, axis=1, inplace=True)
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    price_$   abtest vehicle_type  year_of_registration    gearbox  power_p_s  \
# 0   5000.0  control          bus                  2004    manuell        158
# 1   8500.0  control    limousine                  1997  automatik        286
# 2   8990.0     test    limousine                  2009    manuell        102
# 3   4350.0  control   kleinwagen                  2007  automatik         71
# 4   1350.0     test        kombi                  2003    manuell          0
#
# ...

# %%
autos['price_$'].sort_values(ascending=False).head(20)
# Out:
# 39705    99999999.0
# 42221    27322222.0
# 39377    12345678.0
# 47598    12345678.0
# 27371    12345678.0
# 2897     11111111.0
# 24384    11111111.0
# 11137    10000000.0
# 47634     3890000.0
# 7814      1300000.0
# 22947     1234566.0
# 43049      999999.0
# 514        999999.0
# 37585      999990.0
# 36818      350000.0
# 14715      345000.0
# 34723      299000.0
# 35923      295000.0
# 12682      265000.0
# 47337      259000.0
# Name: price_$, dtype: float64

# %% [markdown]
# oh c'mon... more then 350000 bucks for a second hand car? Are you batman? Wipe!

# %%
autos['price_$'].sort_values(ascending=True).value_counts()
# Out:
# 0.0        1421
# 500.0       781
# 1500.0      734
# 2500.0      643
# 1200.0      639
#            ...
# 8240.0        1
# 44497.0       1
# 11270.0       1
# 9655.0        1
# 18430.0       1
# Name: price_$, Length: 2357, dtype: int64

# %% [markdown]
# Ok let's say that all cars with a price over 350000 and under 1500 are bullshit

# %%
"""bullshit = autos[~autos['price_$'].between(1, 351000)].index
autos.drop(bullshit, axis=0, inplace=True)
autos.reset_index(inplace=True, drop=True)"""
autos = autos[autos['price_$'].between(1, 351000)]
autos.reset_index(inplace=True, drop=True)

autos
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 48560  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 48561  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 48562  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 48563  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 48564  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
autos["price_$"].describe()
# Out:
# count     48565.000000
# mean       5888.935591
# std        9059.854754
# min           1.000000
# 25%        1200.000000
# 50%        3000.000000
# 75%        7490.000000
# max      350000.000000
# Name: price_$, dtype: float64

# %% [markdown]
# Given that eBay is an auction site, there could legitimately be items where the opening bid is \$1. We will keep the \$1 items, but remove anything above $350,000, since it seems that prices increase steadily to that number and then jump up to less realistic numbers.

# %% [markdown]
# ### Exploring the date columns
#
# There are a number of columns with date information:
#
# - `date_crawled`
# - `registration_month`
# - `registration_year`
# - `ad_created`
# - `last_seen`
#
# These are a combination of dates that were crawled, and dates with meta-information from the crawler. The non-registration dates are stored as strings.
#
# We'll explore each of these columns to learn more about the listings.

# %%
autos.loc[0:5, ['date_crawled','date_created','last_seen']]
# Out:
#           date_crawled         date_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50
# 2016-04-01     2.279419
# 2016-04-02     2.491506
# 2016-04-03     2.520334
# 2016-04-04     2.448265
# 2016-04-05    12.476063
# 2016-04-06    22.180583
# 2016-04-07    13.194688
# Name: last_seen, dtype: float64

# %% [markdown]
# The crawler recorded the date it last saw any listing, which allows us to determine on what day a listing was removed, presumably because the car was sold.
#
# The last three days contain a disproportionate amount of 'last seen' values. Given that these are 6-10x the values from the previous days, it's unlikely that there was a massive spike in sales, and more likely that these values are to do with the crawling period ending and don't indicate car sales.

# %%
autos['date_created'].value_counts(normalize=True, dropna=False).sort_index()*100
# Out:
# 2015-06-11    0.002059
# 2015-08-10    0.002059
# 2015-09-09    0.002059
# 2015-11-10    0.002059
# 2015-12-05    0.002059
#                 ...
# 2016-04-03    3.885514
# 2016-04-04    3.685782
# 2016-04-05    1.181921
# 2016-04-06    0.325337
# 2016-04-07    0.125605
# Name: date_created, Length: 76, dtype: float64

# %% [markdown]
# There is a large variety of ad created dates. Most fall within 1-2 months of the listing date, but a few are quite old, with the oldest at around 9 months.

# %%
autos['year_of_registration'].describe()
# Out:
# count    48565.000000
# mean      2004.755421
# std         88.643887
# min       1000.000000
# 25%       1999.000000
# 50%       2004.000000
# 75%       2008.000000
# max       9999.000000
# Name: year_of_registration, dtype: float64

# %% [markdown]
# The year that the car was first registered will likely indicate the age of the car. Looking at this column, we note some odd values. The minimum value is 1000, long before cars were invented and the maximum is 9999, many years into the future.

# %% [markdown]
# ### Dealing with incorrect registration year data

# %% [markdown]
# Because a car can't be first registered after the listing was seen, any vehicle with a registration year above 2016 is definitely inaccurate. Determining the earliest valid year is more difficult. Realistically, it could be somewhere in the first few decades of the 1900s.
#
# Let's count the number of listings with cars that fall outside the 1900 - 2016 interval and see if it's safe to remove those rows entirely, or if we need more custom logic.

# %%
autos = autos[autos['year_of_registration'].between(1900, 2016)]
autos.reset_index(inplace=True, drop=True)

# %%
autos['year_of_registration'].value_counts(normalize=True).sort_index().tail(60)*100
# Out:
# 1957    0.004284
# 1958    0.008569
# 1959    0.012853
# 1960    0.049271
# 1961    0.012853
# 1962    0.008569
# 1963    0.017138
# 1964    0.025706
# 1965    0.036417
# 1966    0.047128
# 1967    0.055697
# 1968    0.055697
# 1969    0.040702
# 1970    0.081404
# 1971    0.055697
# 1972    0.070693
# 1973    0.049271
# 1974    0.051413
# 1975    0.038560
# 1976    0.044986
# 1977    0.047128
# 1978    0.094257
# 1979    0.072835
# 1980    0.182087
# 1981    0.059982
# 1982    0.087830
# 1983    0.109252
# 1984    0.109252
# 1985    0.203509
# 1986    0.154238
# 1987    0.154238
# 1988    0.289197
# 1989    0.372743
# 1990    0.743343
# 1991    0.726206
# 1992    0.792614
# 1993    0.910435
# 1994    1.347443
# 1995    2.628478
# 1996    2.941239
# 1997    4.179431
# 1998    5.062017
# 1999    6.205951
# 2000    6.760781
# 2001    5.646837
# 2002    5.325507
# 2003    5.781796
# 2004    5.790364
# 2005    6.289497
# 2006    5.719672
# 2007    4.877788
# 2008    4.744971
# ...

# %% [markdown]
# ### Exploring price by brand

# %%
autos['brand'].describe()
# Out:
# count          46681
# unique            40
# top       volkswagen
# freq            9862
# Name: brand, dtype: object

# %%
autos['brand'].value_counts(normalize=True).head(20)*100
# Out:
# volkswagen        21.126368
# bmw               11.004477
# opel              10.758124
# mercedes_benz      9.646323
# audi               8.656627
# ford               6.989996
# renault            4.714980
# peugeot            2.984083
# fiat               2.564212
# seat               1.827296
# skoda              1.640925
# nissan             1.527388
# mazda              1.518819
# smart              1.415994
# citroen            1.400998
# toyota             1.270324
# hyundai            1.002549
# sonstige_autos     0.981127
# volvo              0.914719
# mini               0.876159
# Name: brand, dtype: float64

# %% [markdown]
# We're aggregating the firste 20 brands

# %%
brands = autos['brand'].value_counts().head(20)
brands_dict = {'brand': [], 'mean_price_$': [], 'freq': [], 'freq/price': []}
freq_list = []

for row in brands.iteritems():
    brand = row[0]
    freq = row[1]
    mean = int(autos[autos['brand'] == brand]['price_$'].sum() / freq)
    brands_dict['brand'].append(brand)
    brands_dict['mean_price_$'].append(mean)
    brands_dict['freq'].append(freq)
    brands_dict['freq/price'].append(freq/mean)    
    
brands_info_df = pd.DataFrame(brands_dict) 
brands_info_df.sort_values(by='mean_price_$', ascending=False)
# Out:
#              brand  mean_price_$  freq  freq/price
# 17  sonstige_autos         12338   458    0.037121
# 19            mini         10613   409    0.038538
# 4             audi          9336  4041    0.432841
# 3    mercedes_benz          8628  4503    0.521905
# 1              bmw          8332  5137    0.616539
# 10           skoda          6368   766    0.120289
# 0       volkswagen          5402  9862    1.825620
# 16         hyundai          5365   468    0.087232
# 15          toyota          5167   593    0.114767
# 18           volvo          4946   427    0.086332
# 11          nissan          4743   713    0.150327
# 9             seat          4397   853    0.193996
# 12           mazda          4112   709    0.172422
# 14         citroen          3779   654    0.173062
# 5             ford          3749  3263    0.870365
# 13           smart          3580   661    0.184637
# 7          peugeot          3094  1393    0.450226
# ...

# %%
brand_mean_mileage = []
for row in brands.iteritems():
    brand = row[0]
    brand_only = autos[autos["brand"] == brand]
    mean_mileage = brand_only["odometer_km"].mean()
    brand_mean_mileage.append(int(mean_mileage))
    
mean_mileage = pd.Series(brand_mean_mileage).sort_values(ascending=False)
brands_info_df['mean_mileage_km'] = mean_mileage
brands_info_df
# Out:
#              brand  mean_price_$  freq  freq/price  mean_mileage_km
# 0       volkswagen          5402  9862    1.825620           128707
# 1              bmw          8332  5137    0.616539           132572
# 2             opel          2975  5022    1.688067           129310
# 3    mercedes_benz          8628  4503    0.521905           130788
# 4             audi          9336  4041    0.432841           129157
# 5             ford          3749  3263    0.870365           124266
# 6          renault          2474  2201    0.889652           128071
# 7          peugeot          3094  1393    0.450226           127153
# 8             fiat          2813  1197    0.425524           117121
# 9             seat          4397   853    0.193996           121131
# 10           skoda          6368   766    0.120289           110848
# 11          nissan          4743   713    0.150327           118330
# 12           mazda          4112   709    0.172422           124464
# ...

# %% [markdown]
# The range of car mileages does not vary as much as the prices do by brand, instead all falling within 10% for the top brands. There is a slight trend to the more expensive vehicles having higher mileage, with the less expensive vehicles having lower mileage.
