# %% [markdown]
# ## Introduction
#
# Each row in the dataset represents a different major in college and contains information on gender diversity, employment rates, median salaries, and more. Here are some of the columns in the dataset:
#
# - `Rank` - Rank by median earnings (the dataset is ordered by this column).
# - `Major_code` - Major code.
# - `Major` - Major description.
# - `Major_category` - Category of major.
# - `Total` - Total number of people with major.
# - `Sample_size` - Sample size (unweighted) of full-time.
# - `Men` - Male graduates.
# - `Women` - Female graduates.
# - `ShareWomen` - Women as share of total.
# - `Employed` - Number employed.
# - `Median` - Median salary of full-time, year-round workers.
# - `Low_wage_jobs` - Number in low-wage service jobs.
# - `Full_time` - Number employed 35 hours or more.
# - `Part_time` - Number employed less than 35 hours.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
recent_grads = pd.read_csv('recent-grads.csv')

# %%
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  ...  \
# 168    Biology & Life Science    0.637293           47      6259  ...
# 169  Psychology & Social Work    0.817099            7      2125  ...
# 170  Psychology & Social Work    0.799859           13      2101  ...
# 171  Psychology & Social Work    0.798746           21      3777  ...
# 172                 Education    0.877960            2       742  ...
#
#      Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = recent_grads.shape[0]
recent_grads.dropna(inplace=True)
cleaned_data_count = recent_grads.shape[0]

# %% [markdown]
# ### Exploring with scatter plot

# %% [markdown]
# `Sample_size` and `Median`

# %%
recent_grads.plot(x='Sample_size', y='Median', kind='scatter')

# %% [markdown]
# `Sample_size` and `Unemployment_rate`

# %%
recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')

# %% [markdown]
# `Full_time` and `Median`

# %%
recent_grads.plot(x='Full_time', y='Median', kind='scatter')

# %% [markdown]
# `ShareWomen` and `Unemployment_rate`

# %%
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')

# %% [markdown]
# `Men` and `Median`

# %%
recent_grads.plot(x='Men', y='Median', kind='scatter')

# %% [markdown]
# `Women` and `Median`

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter')

# %% [markdown]
# ### Questions

# %% [markdown]
# #### Do students that majored in subjects that were majority female make more money?

# %%
recent_grads.plot(x='ShareWomen', y='Median', kind='scatter')

# %% [markdown]
# There's a weak negative correlation between a majority of female students and a higher medium salary in full time jobs

# %% [markdown]
# #### Do students in more popular majors make more money?

# %%
recent_grads.plot(x='Sample_size', y='Median', kind='scatter')

# %% [markdown]
# nope.

# %% [markdown]
# #### Is there any link between the number of full-time employees and median salary?

# %%
recent_grads.plot(x='Full_time', y='Median', kind='scatter')

# %% [markdown]
# Elements form major with a smaller part for fulltime worker seems to have likely a median higher salary. This suggest a negative(?) correlation beetween the columns `Full_time` and `Median`

# %% [markdown]
# ### Exploring with hist plot

# %%
cols = ['Sample_size', 'Median', 'Employed', 'Full_time', 'ShareWomen', 'Unemployment_rate', 'Men', 'Women']

fig = plt.figure(figsize=(10, 24))
for r in range(1, 9):
    fig.add_subplot(8,1,r)
    recent_grads[cols[r-1]].plot(bins=25, kind='hist', title=cols[r-1], rot=40)
    
fig.tight_layout()

# %% [markdown]
# ### Questions

# %% [markdown]
# #### What percent of majors are predominantly male? Predominantly female?

# %%
major_women = recent_grads[recent_grads['ShareWomen'] > 0.5][['Major', 'Total', 'Men', 'Women']]
major_women.sort_values('Women', ascending=False)
# Out:
#                                           Major     Total       Men     Women
# 145                                  PSYCHOLOGY  393735.0   86648.0  307087.0
# 34                                      NURSING  209394.0   21773.0  187621.0
# 123                                     BIOLOGY  280709.0  111762.0  168947.0
# 138                        ELEMENTARY EDUCATION  170862.0   13029.0  157833.0
# 93                               COMMUNICATIONS  213996.0   70619.0  143377.0
# ..                                          ...       ...       ...       ...
# 172                             LIBRARY SCIENCE    1098.0     134.0     964.0
# 7                    ASTRONOMY AND ASTROPHYSICS    1792.0     832.0     960.0
# 83                                       BOTANY    1329.0     626.0     703.0
# 55                    SCHOOL STUDENT COUNSELING     818.0     119.0     699.0
# 120  EDUCATIONAL ADMINISTRATION AND SUPERVISION     804.0     280.0     524.0
#
# [96 rows x 4 columns]

# %%
print('Percent of majors predominantly female:', (len(major_women)/len(recent_grads))*100)
# Out:
# Percent of majors predominantly female: 55.81395348837209

# %%
major_men = recent_grads[recent_grads['ShareWomen'] < 0.5][['Major', 'Total', 'Men', 'Women']]
major_men.sort_values('Men', ascending=False)
# Out:
#                                       Major     Total       Men     Women
# 76   BUSINESS MANAGEMENT AND ADMINISTRATION  329927.0  173809.0  156118.0
# 57                         GENERAL BUSINESS  234590.0  132238.0  102352.0
# 35                                  FINANCE  174506.0  115030.0   59476.0
# 20                         COMPUTER SCIENCE  128319.0   99743.0   28576.0
# 78         POLITICAL SCIENCE AND GOVERNMENT  182621.0   93880.0   88741.0
# ..                                      ...       ...       ...       ...
# 1            MINING AND MINERAL ENGINEERING     756.0     679.0      77.0
# 52         MATHEMATICS AND COMPUTER SCIENCE     609.0     500.0     109.0
# 33   GEOLOGICAL AND GEOPHYSICAL ENGINEERING     720.0     488.0     232.0
# 112                            SOIL SCIENCE     685.0     476.0     209.0
# 73                    MILITARY TECHNOLOGIES     124.0     124.0       0.0
#
# [76 rows x 4 columns]

# %%
print('Percent of majors predominantly male:', (len(major_men)/len(recent_grads))*100)
# Out:
# Percent of majors predominantly male: 44.18604651162791

# %% [markdown]
# #### What's the most common median salary range?

# %%
import math
import operator

max_median = recent_grads['Median'].max()
min_median = recent_grads['Median'].min()
#interval = (max_median - min_median) / 25;
interval = 1000
interval_dict = {}

for val in recent_grads['Median']:
    val = math.floor(val / interval)
    if val in interval_dict:
        interval_dict[val] += 1;
    else:
        interval_dict[val] = 1;
    
sorted_median = sorted(interval_dict.items(), key=operator.itemgetter(1), reverse=True)
lower_edge = (sorted_median[0][0]*interval)
upper_edge = ((sorted_median[0][0]+1)*(interval))
print('Most common median salary range', lower_edge, '-', upper_edge);
# Out:
# Most common median salary range 35000 - 36000

# %% [markdown]
# ### Exploring with scatter matrix plot

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11b5c2240>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11c1c99e8>,
# ...
#       dtype=object)

# %% [markdown]
# ### Questions

# %% [markdown]
# #### Do students that majored in subjects that were majority female make more money?

# %%
scatter_matrix(recent_grads[['ShareWomen', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11b39d908>,
# ...
#       dtype=object)

# %%
share_men = recent_grads['Men'] / recent_grads['Total']
recent_grads['ShareMen'] = share_men

# %%
scatter_matrix(recent_grads[['ShareMen', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11d31e080>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Total', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11e3216d8>,
# ...
#       dtype=object)

# %% [markdown]
# confirmed previos answer

# %% [markdown]
# ### Exploring with bar plot

# %%
recent_grads[:10].plot(x='Major', y='ShareWomen', kind='bar')

# %%
recent_grads[-10:].plot(x='Major', y='ShareWomen', kind='bar')

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate')

# %%
recent_grads[-10:].plot(x='Major', y='Unemployment_rate', kind='bar')
